# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Kirti\Desktop\Unemployment Analysis\dataset\Unemployment in India.csv")
covid_df=pd.read_csv(r"C:\Users\Kirti\Desktop\Unemployment Analysis\dataset\Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# Main Dataset

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df.shape
# Out:
# (768, 7)

# %% [markdown]
# Covid Dataset

# %%
covid_df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
covid_df.shape
# Out:
# (267, 9)

# %% [markdown]
# Cleaning column names

# %%
df.columns=df.columns.str.strip()
covid_df.columns=covid_df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
print(covid_df.columns)
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# Checking missing values

# %%
df.isnull().sum()
# Out:
# Region                                     28
# Date                                       28
# Frequency                                  28
# Estimated Unemployment Rate (%)            28
# Estimated Employed                         28
# Estimated Labour Participation Rate (%)    28
# Area                                       28
# dtype: int64

# %%
covid_df.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Region.1                                   0
# longitude                                  0
# latitude                                   0
# dtype: int64

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
#Converting date column
df = df.copy()
covid_df = covid_df.copy()

df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
covid_df['Date'] = pd.to_datetime(covid_df['Date'], dayfirst=True)

# %%
#Creating month and year column
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month

covid_df['Year']=covid_df['Date'].dt.year 
covid_df['Month']=covid_df['Date'].dt.month

# %%
df.describe()
# Out:
#                                 Date  Estimated Unemployment Rate (%)  \
# count                            740                       740.000000
# mean   2019-12-12 18:36:58.378378496                        11.787946
# min              2019-05-31 00:00:00                         0.000000
# 25%              2019-08-31 00:00:00                         4.657500
# 50%              2019-11-30 00:00:00                         8.350000
# 75%              2020-03-31 00:00:00                        15.887500
# max              2020-06-30 00:00:00                        76.740000
# std                              NaN                        10.721298
#
#        Estimated Employed  Estimated Labour Participation Rate (%)  \
# count        7.400000e+02                               740.000000
# mean         7.204460e+06                                42.630122
# min          4.942000e+04                                13.330000
# ...

# %%
df['Region'].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df['Region'].nunique()
# Out:
# 28

# %% [markdown]
# Average Unemployment Rate

# %%
avg_unemployment=df['Estimated Unemployment Rate (%)'].mean()
print("Average Unemployment Rate : ",avg_unemployment)
# Out:
# Average Unemployment Rate :  11.787945945945946

# %% [markdown]
# Highest Unemployment Rate

# %%
highest_unemployment=df['Estimated Unemployment Rate (%)'].max()
print("Highest Unemployment Rate : ",highest_unemployment)
# Out:
# Highest Unemployment Rate :  76.74

# %% [markdown]
# Unemployment Distribution

# %%
plt.figure(figsize=(9,5))
sns.histplot(df['Estimated Unemployment Rate (%)'],bins=20,kde=True)
plt.title("Distribution of Unemployment Rate (%)")
plt.xlabel("Unemployment Rate (%) ")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Sate wise average unemployment

# %%
state_avg=df.groupby('Region')['Estimated Unemployment Rate (%)'].mean()

# %%
state_avg=state_avg.sort_values(ascending=False)

# %%
plt.figure(figsize=(14,10))
sns.barplot(x=state_avg.values,y=state_avg.index)
plt.title("Average Unemployment Rate by State")
plt.xlabel("Average Unemployment Rate")
plt.ylabel("Sate")
plt.show()

# %% [markdown]
# Monthly Trend Analysis

# %%
monthly_trend=df.groupby('Date')['Estimated Unemployment Rate (%)'].mean()

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_trend.index,monthly_trend.values)
plt.title("Monthly Unemployment Trend")
plt.xlabel("Date")
plt.ylabel("Average Une mployment Rate")

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Covid - 19 Impact Analysis

# %% [markdown]
# Average unemployment during COVID

# %%
covid_avg=covid_df['Estimated Unemployment Rate (%)'].mean()
print("Average Unemployment During COVID : ",covid_avg)
# Out:
# Average Unemployment During COVID :  12.236928838951311

# %% [markdown]
# COVID Trend

# %%
covid_trend=covid_df.groupby('Date')['Estimated Unemployment Rate (%)'].mean()

# %%
plt.figure(figsize=(10,4))
plt.plot(covid_trend.index,covid_trend.values,marker='o')
plt.title("Covid-19 Unemploymnet Trend")
plt.xlabel("Date")
plt.ylabel("Unemployment Rate")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Before Vs During Covid

# %%
before_covid=df['Estimated Unemployment Rate (%)'].mean()

# %%
during_covid=covid_df['Estimated Unemployment Rate (%)'].mean()

# %%
comparison=pd.DataFrame({'Period':['Before COVID','During COVID'],'Average Unemployment Rate':[before_covid,during_covid]})

# %%
comparison
# Out:
#          Period  Average Unemployment Rate
# 0  Before COVID                  11.787946
# 1  During COVID                  12.236929

# %%
plt.figure(figsize=(8,3))
sns.barplot(x='Period',y='Average Unemployment Rate',data=comparison)
plt.title("Before Vs During Covid Unemployment_Analysis.ipynb.ipynb")
plt.show()

# %% [markdown]
# Area Wise Analysis

# %%
area_avg=df.groupby('Area')['Estimated Unemployment Rate (%)'].mean()

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=area_avg.index,y=area_avg.values)
plt.title("Urban Vs Rural Unemployment_Analysis")
plt.xlabel("Area")
plt.ylabel("Average Unemployment Rate")
plt.show()

# %% [markdown]
# Correlation Heatmap

# %%
numeric_df=df.select_dtypes(include=np.number)

# %%
plt.figure(figsize=(9,6))
sns.heatmap(numeric_df.corr(),annot=True,cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# Seasonal Trend Analysis

# %%
monthly_avg=df.groupby('Month')['Estimated Unemployment Rate (%)'].mean()

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=monthly_avg.index,y=monthly_avg.values,marker='o')
plt.title("Seasonal Monthly Unemployment Trend")
plt.xlabel("Month")
plt.ylabel("Average Unemployment Rate")
plt.show()

# %% [markdown]
# Top 10 states with Highest Unemployment

# %%
top_states=state_avg.head(10)

# %%
plt.figure(figsize=(6,7))
sns.barplot(x=top_states.values,y=top_states.index)
plt.title("Top 10 Sates eith Highest Unemployment_Analysis")
plt.xlabel("Unemployment Rate")
plt.ylabel("Satte")
plt.show()

# %%
df.to_csv(r"C:\Users\Kirti\Desktop\Unemployment Analysis\dataset\cleaned dataset\cleaned_unemployment_data.csv",index=False)

covid_df.to_csv(r"C:\Users\Kirti\Desktop\Unemployment Analysis\dataset\cleaned dataset\cleaned_covid_unemployment_data.csv",index=False)
